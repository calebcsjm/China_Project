# %%
import pandas as pd

articles = pd.read_csv('../process_articles/validated_articles.csv')
print(f'Articles shape: {articles.shape}')
# Out:
# Articles shape: (2014, 9)

# %%
# keep the authors, title, url, and year_quarter
keep = ['authors', 'title', 'year_quarter', 'url']
articles.drop(columns=[column for column in articles.columns if column not in keep], inplace=True)
total_articles = len(articles)
# save a csv so I can find the authors easily
articles.to_csv('./author_info/articles.csv')
print(f'Articles shape: {articles.shape}')

# then drop any that are missing the author data
articles.dropna(subset=['authors'], axis=0, inplace=True)
articles_w_author = len(articles)
print(f'Articles shape: {articles.shape}')
# Out:
# Articles shape: (2014, 4)
# Articles shape: (1714, 4)

# %% [markdown]
# I need to begin with the end in mind - what is the research question?
#
# Questions:
# - Who are the most important voices in Qiushi (as measured by frequency - which may not be the best metric)?
# - Have the most important voices changed over time?
# - Who are the most important writers on a given topic? - how to tell if it is on a given topic? If it is in the title, is that enough?
#
# To track frequency over time, maybe have a table with authors as rows, and then two columns for each quarter: one with an article count, and another with the titles for that quarter?
#
# I want to get the total article count for each author, and also be able to do an articles/quarter count for each of them

# %%
# start with a simple count per author
author_article_count = {}

from ast import literal_eval

for index, article in articles.iterrows():
    for author in literal_eval(article['authors']):
        if author in author_article_count.keys():
            temp = author_article_count[author]
            author_article_count[author] = temp + 1
        else: 
            author_article_count[author] = 1

author_article_count
# Out:
# {'习近平': 123,
#  '《求是》杂志编辑部': 72,
#  '王毅': 11,
#  '《求是》杂志评论员': 76,
#  '国家发展和改革委员会': 9,
#  '中共江苏省委': 1,
#  '中共深圳市委': 1,
#  '铁凝': 6,
#  '王可': 1,
#  '周昭成': 8,
#  '陈聪': 4,
#  '聂悄语': 1,
#  '黎海华': 10,
#  '吴擒虎': 1,
#  '梁佩韵': 12,
#  '刘骏娇': 1,
#  '李飞': 3,
#  '姜小薇': 1,
#  '李豪杰': 1,
#  '王文涛': 4,
#  '侯凯': 1,
#  '李文章': 2,
#  '左中一': 2,
#  '曲莹璞': 1,
#  '谭瑞松': 1,
#  '习近平生态文明思想研究中心': 3,
#  '北京市习近平新时代中国特色社会主义思想研究中心': 3,
#  '魏天舒': 8,
#  '吉文磊': 1,
#  '蔡春玲': 7,
#  '樊遂桥': 1,
#  '申小提': 3,
#  '张颐佳': 1,
#  '狄英娜': 10,
#  '翟汝增': 1,
#  '何雨奇': 1,
#  '《机关党建研究》评论员': 3,
#  '中共中央党校（国家行政学院）校（院）务委员会': 3,
#  '中共中央党史和文献研究院院务会理论学习中心组': 4,
#  '共青团中央书记处理论学习中心组': 1,
#  '中共中国社会科学院党组': 3,
#  '倪岳峰': 3,
#  '王宁': 1,
#  '慎海雄': 10,
#  '余剑锋': 2,
#  '沈壮海': 3,
#  '盛玮': 7,
#  '吴晓迪': 4,
#  '杜晨薇': 1,
#  '陈有勇': 8,
#  '王磊': 1,
#  '刘忠培': 1,
#  '《中国纪检监察》评论员': 5,
#  '中共上海市委': 4,
#  '景俊海': 4,
#  '金壮龙': 1,
#  '刘昆': 4,
#  '中共全国工商联党组': 2,
#  '中共国家统计局党组': 7,
#  '徐艳玲': 1,
#  '王成果': 1,
#  '周璐铭': 6,
#  '张春林': 2,
#  '旷思思': 9,
#  '章丹': 1,
#  '侯亚景': 12,
#  '咸文静': 2,
#  '王志琦': 1,
#  '秦九鸿': 1,
#  '新华社记者': 38,
#  '钧政': 3,
#  '庄荣文': 2,
#  '中共全国妇联党组': 3,
#  '全国人大常委会法制工作委员会': 4,
#  '程同顺': 1,
#  '贺军科': 3,
#  '吴桂英': 1,
#  '孙树志': 1,
#  '谭雅竹': 2,
#  '张淑虹': 5,
#  '汪纯': 1,
#  '李民圣': 6,
#  '李旭': 1,
#  '刘汝山': 1,
#  '辛湘平': 4,
#  '唐仁健': 3,
#  '中共吉林省委': 1,
#  '吉林省人民政府': 1,
#  '中共河南省委': 1,
#  '中共内蒙古自治区委员会': 1,
#  '高天鼎': 8,
#  '李宏伟': 1,
#  '刘秉承': 1,
#  '陈金霞': 2,
#  '王嘉楠': 1,
#  '伏润之': 2,
#  '秦文敏': 1,
#  '群仲平': 3,
#  '《当代广西》评论员': 2,
#  '曹文泽': 1,
#  '梅黎明': 1,
#  '姜泽洵': 1,
#  '中共西藏自治区委员会': 3,
#  '刘建超': 2,
#  '马晓伟': 3,
#  '双传学': 1,
#  '李斌': 1,
#  '周文强': 1,
#  '纪红建': 1,
#  '孙明增': 2,
#  '郑建邦': 1,
#  '訚柏': 1,
#  '陈一新': 6,
#  '王灵桂': 2,
#  '曲青山': 10,
#  '中共财政部党组': 1,
#  '李国英': 1,
#  '齐玉': 2,
#  '信长星': 1,
#  '王蒙徽': 2,
#  '国务院国资委党委': 6,
#  '郑庆东': 1,
#  '沈志华': 1,
#  '广东省习近平新时代中国特色社会主义思想研究中心': 2,
#  '张伯军': 1,
#  '李洪斌': 1,
#  '《南方》杂志编辑部': 2,
#  '秦刚': 2,
#  '中共教育部党组': 6,
#  '徐麟': 1,
#  '中共北京市委理论学习中心组': 4,
#  '任鸿斌': 1,
#  '丁焰章': 1,
#  '张军': 4,
#  '童朝晖': 1,
#  '赵凝': 1,
#  '刘振峰': 1,
#  '杨文娟': 1,
#  '刘祥元': 1,
#  '肖纯柏': 1,
#  '本貌': 1,
#  '专题调研组': 2,
#  '王晓萍': 2,
#  '王广华': 1,
#  '中共山东省委': 2,
#  '周祖翼': 3,
#  '求是杂志社、云南省委联合调研组': 2,
#  '孙煜华': 1,
#  '宋东泽': 1,
#  '孙洋洋': 3,
#  '刘名美': 7,
#  '《今日浙江》评论员': 1,
#  '中共浙江省委': 3,
#  '全国人大常委会机关党组理论学习中心组': 1,
#  '人民日报编委会理论学习中心组': 2,
#  '中共中华全国总工会党组': 1,
#  '求是杂志社调研组': 5,
#  '邱勇': 2,
#  '丁燕': 1,
#  '苏晓琼': 1,
#  '李孝': 1,
#  '《奋斗》评论员': 3,
#  '全国政协机关党组理论学习中心组': 1,
#  '新华社党组理论学习中心组': 1,
#  '蓝佛安': 1,
#  '郑栅洁': 2,
#  '中共水利部党组': 3,
#  '王文婷': 3,
#  '赵嘉宾': 1,
#  '张志晓': 1,
#  '中共新疆维吾尔自治区委员会': 2,
#  '国防大学习近平新时代中国特色社会主义思想研究中心': 3,
#  '阿东': 1,
#  '中国文联党组': 2,
#  '怀进鹏': 2,
#  '李坤': 2,
#  '那非丁': 3,
#  '杨世智': 1,
#  '韩融': 1,
#  '侯逸宁': 1,
#  '王学典': 1,
#  '中共中国科学院党组': 3,
#  '中共中国科学技术大学委员会': 1,
#  '军事科学院': 2,
#  '中央组织部党建研究所': 2,
#  '生态环境部': 3,
#  '韩俊': 1,
#  '王曼倩': 1,
#  '王志刚': 5,
#  '刘宁': 3,
#  '梁言顺': 2,
#  '中共中国作家协会党组': 2,
#  '中共中国出版集团有限公司党组': 1,
#  '何雯雯': 7,
#  '徐阳': 1,
#  '钟联': 3,
#  '中国历史研究院': 2,
#  '中国国家版本馆': 1,
#  '李群': 2,
#  '中央军委国防动员部': 1,
#  '中共工业和信息化部党组': 3,
#  '马永生': 1,
#  '上海市习近平新时代中国特色社会主义思想研究中心': 2,
#  '黄炜信': 1,
#  '孙云': 1,
#  '施郑平': 1,
#  '中共中国人民大学委员会': 3,
#  '中共复旦大学委员会': 1,
#  '中共西安交通大学委员会': 1,
#  '中共湖南省委': 5,
#  '中国残疾人联合会': 3,
#  '谭成旭': 1,
#  '卜宪群': 1,
#  '李雪睿': 1,
#  '《当代贵州》评论员': 1,
#  '中共国家发展改革委党组': 5,
#  '中共北京市委': 4,
#  '李小鹏': 1,
#  '王军': 3,
#  '蒋建国': 1,
#  '中国新闻社': 1,
#  '中国机械工业集团有限公司党委': 1,
#  '张昕': 1,
#  '赵永生': 1,
#  '庹震': 1,
#  '傅华': 1,
#  '中共重庆市委': 2,
#  '倪虹': 1,
#  '中国（上海）自由贸易试验区管委会': 1,
#  '黄群慧': 1,
#  '江东灿': 1,
#  '中共审计署党组': 1,
#  '王东明': 6,
#  '中共福建省委': 2,
#  '中共文化和旅游部党组': 1,
#  '李屹': 2,
#  '空军党委': 2,
#  '王小蕾': 1,
#  '自然资源部': 2,
#  '国家林业和草原局': 1,
#  '谌贻琴': 2,
#  '中央网络安全和信息化委员会办公室室务会': 1,
#  '易炼红': 3,
#  '郝鹏': 3,
#  '许勤': 2,
#  '陈晋': 4,
#  '宋小红': 1,
#  '中央金融委员会办公室\u3000中央金融工作委员会': 1,
#  '冯飞': 1,
#  '裴金佳': 1,
#  '曹淑敏': 1,
#  '王春法': 1,
#  '郑莉': 1,
#  '万建武': 2,
#  '李雯博': 2,
#  '邱霞': 1,
#  '杨璐蔓': 1,
#  '陈文清': 4,
#  '中央机构编制委员会办公室': 2,
#  '中共中央党史和文献研究院': 10,
#  '孙绍骋': 3,
#  '潘岳': 1,
#  '高翔': 1,
#  '王涛': 2,
#  '王伟光': 2,
#  '吴政隆': 2,
#  '唐一军': 3,
#  '肖裕声': 1,
#  '袁绍光': 1,
#  '武汉大学国家发展战略智库课题组': 1,
#  '梅宏': 1,
#  '陈理': 2,
#  '文平': 2,
#  '中共中央组织部': 4,
#  '张宏志': 2,
#  '宁吉喆': 13,
#  '关志鸥': 1,
#  '中共中国国家铁路集团有限公司党组': 1,
#  '柯文': 1,
#  '杨子强': 1,
#  '周名阳': 1,
#  '周强': 3,
#  '孙金龙': 3,
#  '中共交通运输部党组': 3,
#  '海军党委': 2,
#  '张鹏飞': 1,
#  '王一帆': 1,
#  '中共北京市人大常委会党组': 1,
#  '中共湖北省人大常委会党组': 1,
#  '肖开提·依明': 1,
#  '白春礼': 2,
#  '郭斐然': 4,
#  '秋菊': 1,
#  '李达': 4,
#  '余婧': 1,
#  '刘中': 1,
#  '中共政协全国委员会机关党组': 2,
#  '中共福建省政协党组': 1,
#  '中共西藏自治区政协党组': 1,
#  '中共重庆市委理论学习中心组': 1,
#  '王东峰': 4,
#  '石泰峰': 2,
#  '陈亦琳': 2,
#  '王春楠': 1,
#  '杨绍华': 3,
#  '倪琴': 1,
#  '尹霞': 4,
#  '梁生树': 2,
#  '李彬': 1,
#  '韩燕': 1,
#  '王云': 1,
#  '何勤华': 1,
#  '张厚美': 1,
#  '李育蒙': 3,
#  '刘艳辉': 2,
#  '李干杰': 3,
#  '楼阳生': 2,
#  '中共中国建筑集团有限公司党组': 1,
#  '尹力': 2,
#  '王力': 1,
#  '郑亚丽': 1,
#  '蔡萌': 3,
#  '中共民政部党组': 3,
#  '中共人力资源和社会保障部党组': 3,
#  '中共国家医疗保障局党组': 1,
#  '中国社会科学院习近平新时代中国特色社会主义思想研究中心': 2,
#  '李连成': 1,
#  '赵丰': 1,
#  '董凤龙': 1,
#  '张智伟': 1,
#  '石雷': 1,
#  '中央军委国防动员部党委': 1,
#  '宗平': 2,
#  '李龙': 1,
#  '中共中国科学技术协会党组': 2,
#  '中共科学技术部党组': 2,
#  '侯建国': 3,
#  '李晓红': 3,
#  '丁佳文': 3,
#  '段利军': 1,
#  '姜斌': 1,
#  '岳劲松': 3,
#  '郑颖': 2,
#  '周晓辉': 1,
#  '钟国安': 1,
#  '马建堂': 2,
#  '中国银保监会党委': 1,
#  '中共国家粮食和物资储备局党组': 2,
#  '王金南': 1,
#  '蔡博峰': 1,
#  '龙丹梅': 1,
#  '李贵文': 1,
#  '张猛': 1,
#  '潘彦云': 1,
#  '王均伟': 4,
#  '刘汉峰': 1,
#  '陆昊': 1,
#  '中共水利部党组理论学习中心组': 1,
#  '雷鸣山': 1,
#  '林武': 1,
#  '沈晓明': 1,
#  '刘玉成': 2,
#  '孙大卫': 1,
#  '张力军': 1,
#  '李孝纯': 3,
#  '晏培娟': 1,
#  '朱林': 1,
#  '郭声琨': 2,
#  '陈刚': 1,
#  '鲁广锦': 1,
#  '史泽奇': 1,
#  '贾红路': 1,
#  '黄志武': 1,
#  '朱兴': 1,
#  '陈志勇': 1,
#  '武汉大学马克思主义学院': 1,
#  '中共广东省委': 2,
#  '李保健': 1,
#  '王珊珊': 1,
#  '周亚明': 1,
#  '肖亮': 1,
#  '陈智辉': 1,
#  '杨洁篪': 6,
#  '中国国家博物馆': 1,
#  '河南博物院': 1,
#  '良渚博物院': 1,
#  '三星堆博物馆': 1,
#  '王巍': 2,
#  '朱诚如': 1,
#  '白续宏': 1,
#  '柴潇凡': 4,
#  '陈凌墨': 2,
#  '秦丽云': 1,
#  '中央广播电视总台党组、编务会议': 1,
#  '中共国家卫生健康委党组': 2,
#  '易会满': 1,
#  '辛保安': 1,
#  '求是杂志社、福建省委联合调研组': 1,
#  '张大鹏': 1,
#  '陈文君': 1,
#  '曹雯': 1,
#  '田运栋': 1,
#  '中共生态环境部党组': 1,
#  '周育先': 1,
#  '孙永才': 1,
#  '翁杰': 1,
#  '刘勇': 1,
#  '王学志': 1,
#  '尤权': 3,
#  '中共安徽省委': 2,
#  '冷兴邦': 1,
#  '李抑嫱': 1,
#  '王瑞欣': 1,
#  '王文武': 1,
#  '志晟': 1,
#  '中央党校（国家行政学院）习近平新时代中国特色社会主义思想研究中心': 1,
#  '人民日报编委会': 1,
#  '殷皓': 1,
#  '梁伟新': 1,
#  '柳萍': 1,
#  '龚砚庆': 1,
#  '张文博': 1,
#  '李志廷': 1,
#  '马卓勋': 1,
#  '谢尚芸': 1,
#  '王春英': 1,
#  '江苏省习近平新时代中国特色社会主义思想研究中心': 1,
#  '王如': 1,
#  '颜晓峰': 1,
#  '宰飞': 1,
#  '张冠年': 1,
#  '韩小南': 1,
#  '教育部习近平新时代中国特色社会主义思想研究中心': 1,
#  '浙江省习近平新时代中国特色社会主义思想研究中心': 1,
#  '山东省习近平新时代中国特色社会主义思想研究中心': 2,
#  '吴燕生': 1,
#  '戴厚良': 2,
#  '张伟': 1,
#  '中国铁路工程集团有限公司党委': 1,
#  '钟波': 1,
#  '金晓玲': 1,
#  '赵星月': 1,
#  '马军权': 1,
#  '陈诚': 1,
#  '张旭东': 2,
#  '丁小溪': 2,
#  '江金权': 3,
#  '谢伏瞻': 4,
#  '穆虹': 2,
#  '中共中国文联党组': 1,
#  '夏红民': 3,
#  '金冲及': 3,
#  '李纪恒': 3,
#  '钟新': 1,
#  '刘结一': 2,
#  '中共国家发展和改革委员会党组': 2,
#  '陆军党委': 3,
#  '中共江苏省委组织部': 1,
#  '孙敏': 1,
#  '方炜杭': 1,
#  '刘晓波': 1,
#  '蒋君芳': 1,
#  '张国祚': 1,
#  '宋涛': 3,
#  '姜信治': 1,
#  '中央全面依法治国委员会办公室': 4,
#  '唐方裕': 2,
#  '张克俭': 1,
#  '中国华能集团有限公司党组': 1,
#  '孙娇杨': 1,
#  '纪伟': 1,
#  '张文峰': 1,
#  '辛声': 2,
#  '赵克志': 1,
#  '王岗罡': 1,
#  '季思': 3,
#  '栗战书': 1,
#  '中共中央统一战线工作部': 1,
#  '冷溶': 2,
#  '马兴瑞': 3,
#  '詹成付': 2,
#  '中共三明市委': 1,
#  '夏澍耘': 1,
#  '王晨': 4,
#  '申长雨': 1,
#  '国家版权局': 1,
#  '最高人民法院知识产权审判庭': 1,
#  '国家发展改革委政策研究室': 2,
#  '陈大昊': 1,
#  '《当代江西》评论员': 1,
#  '高志顺': 1,
#  '马彦铭': 1,
#  '潘文静': 1,
#  '中共国家乡村振兴局党组': 1,
#  '姜辉': 2,
#  '闫玉清': 4,
#  '宗言': 2,
#  '海华': 2,
#  '徐川': 1,
#  '同心': 14,
#  '中共云南省委': 1,
#  '黄曦': 2,
#  '李锦斌': 3,
#  '全国党建研究会课题组': 1,
#  '杨幽红': 1,
#  '朱生营': 1,
#  '中共中央宣传部': 1,
#  '共青团中央': 1,
#  '刘国中': 1,
#  '陈润儿': 2,
#  '唐铮': 1,
#  '国务院港澳事务办公室': 1,
#  '周春男': 1,
#  '韩延明': 1,
#  '张庆黎': 3,
#  '共青团中央书记处': 4,
#  '陈旭': 2,
#  '求是杂志社、中共浙江省杭州市委联合调研组': 1,
#  '陈安娜': 1,
#  '中共江西省委': 1,
#  '中共贵州省委': 1,
#  '中共陕西省委': 1,
#  '中共河北省委': 2,
#  '刘家义': 4,
#  '张磊': 1,
#  '何立峰': 3,
#  '刘慧晏': 1,
#  '徐本禹': 1,
#  '陈清': 1,
#  '张纪南': 1,
#  '求是杂志社、中共江苏省委联合调研组': 1,
#  '中国人民大学、北京市党建研究所联合调研组': 1,
#  '中共中国核工业集团有限公司党组': 1,
#  '方江山': 1,
#  '颜磊': 1,
#  '《求是》社论': 1,
#  '无需答复.': 1,
#  '黄润秋': 2,
#  '中共中国航空工业集团有限公司党组': 1,
#  '罗平汉': 1,
#  '宋庆伟': 1,
#  '沈永福': 1,
#  '孙文亮': 1,
#  '娄勤俭': 2,
#  '庄国泰': 1,
#  '魏传光': 1,
#  '张又侠': 1,
#  '陆东福': 1,
#  '阮成发': 1,
#  '王芸婷': 1,
#  '中共中央组织部理论学习中心组': 2,
#  '李仰哲': 1,
#  '王兴宁': 1,
#  '侯淅珉': 1,
#  '许罗德': 1,
#  '习近平外交思想研究中心': 1,
#  '吴向东': 1,
#  '顾海凇': 1,
#  '付松': 1,
#  '刘仁富': 1,
#  '中共中国藏学研究中心党组': 1,
#  '军事科学院军队政治工作研究院': 1,
#  '求是杂志社、中共贵州省委联合调研组': 1,
#  '孙立成': 1,
#  '陶明伦': 1,
#  '张晴': 1,
#  '陈道发': 1,
#  '中国共产党第一次全国代表大会纪念馆': 1,
#  '井冈山革命博物馆': 1,
#  '遵义会议纪念馆': 1,
#  '延安革命纪念馆': 1,
#  '西柏坡纪念馆': 1,
#  '陈四清': 1,
#  '《求是》杂志科教编辑部、中共北京市东城区委联合调研组': 1,
#  '张阳': 1,
#  '钟超': 1,
#  '袁家军': 2,
#  '张晓朴': 1,
#  '刘佳义': 1,
#  '刘绍勇': 1,
#  '中国化学工程集团有限公司党委': 1,
#  '徐闻': 1,
#  '杨丹妮': 1,
#  '杨振武': 1,
#  '中国人民保险集团党委': 1,
#  '中国共产党历史展览馆': 1,
#  '欧阳淞': 1,
#  '信春鹰': 2,
#  '黄晓薇': 1,
#  '张恩惠': 1,
#  '刘陈波': 1,
#  '南旭光': 1,
#  '王辉': 1,
#  '程扬': 1,
#  '中共黑龙江省委': 1,
#  '新华社国家高端智库课题组': 1,
#  '侯天雨': 1,
#  '本刊编辑部': 47,
#  '张晓明': 1,
#  '陈豪': 1,
#  '人力资源和社会保障部党组': 1,
#  '中共湖北省委': 1,
#  '湖北省人民政府': 1,
#  '中央军委训练管理部': 1,
#  '王玉强': 1,
#  '杨黎光': 1,
#  '姜\u3000辉': 1,
#  '罗梅': 1,
#  '袁浩': 2,
#  '本刊评论员': 19,
#  '陈求发': 1,
#  '徐立毅': 1,
#  '马国强': 1,
#  '胡衡华': 1,
#  '唐良智': 1,
#  '中共中央办公厅法规局': 2,
#  '中共公安部委员会': 1,
#  '求是杂志社、江西省委联合调研组': 1,
#  '张经伦': 1,
#  '王伟中': 2,
#  '范锐平': 1,
#  '陈先达': 2,
#  '李学勇': 1,
#  '李宣良': 1,
#  '樊永强': 1,
#  '杨军': 1,
#  '求是杂志社、海南省委宣传部联合调研组': 1,
#  '樊锦诗': 1,
#  '郑洪': 1,
#  '《党建》评论员': 1,
#  '《党建研究》评论员': 1,
#  '江必新': 1,
#  '中共国家卫生健康委员会党组': 2,
#  '钧卫民': 1,
#  '陈芳': 2,
#  '董瑞丰': 2,
#  '田晓航': 1,
#  '李罡': 1,
#  '殷立飞': 1,
#  '张士涛': 1,
#  '江勇': 1,
#  '韩长赋': 2,
#  '胡静林': 1,
#  '国家卫生健康委员会宣传司': 1,
#  '健康报社': 1,
#  '张大庆': 1,
#  '姚瑜坪': 2,
#  '桑林峰': 2,
#  '孙春兰': 1,
#  '应勇': 2,
#  '周芳': 1,
#  '周志兵': 1,
#  '彭小萍': 1,
#  '黄璐': 1,
#  '王子铭': 1,
#  '孙少龙': 1,
#  '黄玥': 2,
#  '钟山': 3,
#  '李利': 1,
#  '焦红': 1,
#  '《共产党员》评论员': 1,
#  '中共中央对外联络部': 2,
#  '许又声': 1,
#  '中共国家国际发展合作署党组': 1,
#  '青原': 5,
#  '陈水胜': 1,
#  '钟纪言': 2,
#  '刘永富': 1,
#  '林铎': 2,
#  '叶子鹏': 1,
#  '朱波': 1,
#  '巨力': 12,
#  '杜飞进': 1,
#  '林晖': 1,
#  '高蕾': 1,
#  '易纲': 2,
#  '司春燕': 1,
#  '国家发展改革委': 3,
#  '本刊编辑部、陕西省委宣传部联合调研组': 1,
#  '秦岭': 1,
#  '刘政': 1,
#  '越名': 1,
#  '汪习根': 1,
#  '郝薇薇': 1,
#  '郑汉根': 1,
#  '商婧': 1,
#  '陈杉': 1,
#  '徐秉国': 1,
#  '倪寿明': 1,
#  '仲祖文': 2,
#  '孙业礼': 1,
#  '徐辉冠': 1,
#  '郭煦': 1,
#  '赵雁': 1,
#  '张少义': 1,
#  '靳晶': 1,
#  '李文刚': 1,
#  '中共中央党校（国家行政学院）': 1,
#  '中共陕西省延安市委': 1,
#  '洛桑江村': 1,
#  '中央广播电视总台党组': 1,
#  '周乃翔': 1,
#  '王光煦': 1,
#  '鄂璠': 2,
#  '王兆斌': 2,
#  '张芯蕊': 1,
#  '张首映': 2,
#  '董晓辉': 1,
#  '黄建发': 1,
#  '杨贤金': 1,
#  '王正谱': 1,
#  '喻云林': 1,
#  '刘强': 1,
#  '唐洲雁': 1,
#  '中央军委政治工作部': 2,
#  '王寅': 2,
#  '韩辰': 2,
#  '包俊洪': 1,
#  '郭玲': 1,
#  '李露倩': 1,
#  '茅文婷': 1,
#  '王德': 1,
#  '刘赐贵': 1,
#  '鄂竟平': 1,
#  '郭树清': 1,
#  '余艳红': 1,
#  '于文明': 1,
#  '周彪': 2,
#  '许华卿': 1,
#  '刘唯达': 1,
#  '潘信林': 1,
#  '韩宇': 1,
#  '陈宝生': 2,
#  '中国少年先锋队全国工作委员会': 1,
#  '杨学军': 1,
#  '方向': 1,
#  '中共浙江省湖州市委': 1,
#  '王慧': 1,
#  '曾嘉雯': 1,
#  '唐淑楠': 1,
#  '李丹华': 1,
#  '李永进': 1,
#  '吴家华': 1,
#  '张利英': 1,
#  '龚紫陌': 1,
#  '周兵': 1,
#  '乔雪': 1,
#  '胡远志': 1,
#  '高霞': 1,
#  '吴英杰': 1,
#  '求是杂志社、广西壮族自治区党委联合调研组': 1,
#  '赵金': 1,
#  '刘健': 1,
#  '李兴文': 1,
#  '侯雪静': 1,
#  '高皓亮': 1,
#  '郭强': 1,
#  '刘建华': 1,
#  '易赛键': 1,
#  '袁帅': 1,
#  '刘玉冰': 1,
#  '李艳玲': 1,
#  '广东省清远市乡村新闻官': 1,
#  '任鹏程': 1,
#  '特约调研组': 2,
#  '中共中央组织部党建研究所': 1,
#  '侍俊': 1,
#  '中共退役军人事务部党组': 1,
#  '李峰': 1,
#  '中共国家机关事务管理局党组': 1,
#  '蔡达峰': 1,
#  '牛月永': 1,
#  '《四川党的建设》特约评论员': 1,
#  '刘玉珠': 1,
#  '中共甘肃省委': 2,
#  '施芝鸿': 1,
#  '张来明': 1,
#  '屈婷': 1,
#  '王厚明': 2,
#  '中共商务部党组': 1,
#  '林尚立': 1,
#  '彭清华': 3,
#  '中共中国工程院党组': 1,
#  '胡昌升': 1,
#  '《求是》杂志经济编辑部、中国石油长庆油田党委联合调研组': 1,
#  '邓联荣': 1,
#  '何忠国': 1,
#  '黄坤明': 2,
#  '新华社改革开放40周年专题调研组': 1,
#  '刘雅鸣': 1,
#  '李亚楠': 1,
#  '宋晓东': 1,
#  '李国强': 1,
#  '董城': 1,
#  '李君': 1,
#  '《中直党建》评论员': 1,
#  '国家统计局': 1,
#  '丁来杭': 2,
#  '于忠福': 2,
#  '高培勇': 1,
#  '新华社半月谈记者': 3,
#  '李继明': 1,
#  '毛盛勇': 1,
#  '马利娟': 1,
#  '全国人民代表大会农业与农村委员会': 1,
#  '于沛': 1,
#  '鄯爱红': 1,
#  '谭铁牛': 1,
#  '中共国家邮政局党组': 1,
#  '闻华': 1,
#  '陈培永': 1,
#  '蒋红': 1,
#  '王德蓉': 1,
#  '国家发展改革委宏观经济研究院': 1,
#  '张维为': 1,
#  '周萌': 1,
#  '刘世军': 1,
#  '赵军': 1,
#  '苗圩': 1,
#  '李颖': 1,
#  '鹤蜚': 1,
#  '王唤春': 1,
#  '郑言实': 1,
#  '蔡名照': 1,
#  '姜淑萍': 1,
#  '张晋藩': 1,
#  '韩毓海': 1,
#  '雷春芳': 1,
#  '胡江萍': 1,
#  '高波': 1,
#  '沈金龙': 1,
#  '秦生祥': 1,
#  '蒋超良': 1,
#  '孔铉佑': 1,
#  '南开大学': 1,
#  '刘建军': 1,
#  '李新烽': 1,
#  '林经纬': 1,
#  '杨巨帅': 1,
#  '言平': 1,
#  '李玲': 1,
#  '中央巡视工作领导小组': 1,
#  '鹿心社': 1,
#  '刘大椿': 1,
#  '徐永辉': 1,
#  '何苏鸣': 1,
#  '马国栋': 1,
#  '宛江平': 1,
#  '胡锡进': 1,
#  '求是杂志社、贵州省委联合调研组': 1,
#  '钱乘旦': 1,
#  '钟纪轩': 1,
#  '陈浙闽': 1,
#  '马一德': 1,
#  '任林举': 1,
#  '梁涛': 1,
#  '田海舰': 1,
#  '李春雷': 1,
#  '林泰': 1,
#  '严昭柱': 1,
#  '强世功': 1,
#  '邱炜煌': 1,
#  '张全景': 1,
#  '张富清': 1,
#  '王启民': 1,
#  '朱佳木': 1,
#  '孔丹': 1,
#  '黄树贤': 1,
#  '吴德刚': 1,
#  '孙波': 1,
#  '沈虹冰': 1,
#  '梁娟': 1,
#  '陈晨': 1,
#  '张斌': 1,
#  '韩卫国': 1,
#  '刘雷': 1,
#  '本刊科教编辑部、《今日浙江》杂志联合调研组': 1,
#  '范志忠': 1,
#  '李万军': 1,
#  '申国华': 1,
#  '全国党的建设研究会': 1,
#  '杨文明': 1,
#  '黄一兵': 1,
#  '胡祖才': 1,
#  '求是杂志社、江苏省委联合调研组': 2,
#  '李舫': 1,
#  '李淼': 1,
#  '侯冲': 1,
#  '樊邦平': 1,
#  '张雨': 1,
#  '梁修明': 1,
#  '中央和国家机关工委理论学习中心组': 1,
#  '逄先知': 1,
#  '郑科扬': 1,
#  '王庭大': 1,
#  '政协全国委员会文化文史和学习委员会调研组': 1,
#  '李清华': 1,
#  '李小三': 1,
#  '刘良军': 1,
#  '王鹏': 1,
#  '蔡建军': 1,
#  '韩璐': 1,
#  '牛廷伟': 1,
#  '本刊调研组': 1,
#  '吴华': 1,
#  '张治立': 1,
#  '中共广西壮族自治区委员会': 1,
#  '乐玉成': 1,
#  '本刊文化编辑部、张家港市委宣传部联合调研组': 1,
#  '顾海良': 1,
#  '刘新圣': 1,
#  '戎旭': 1,
#  '伍正华': 1,
#  '王通化': 1,
#  '唐登杰': 1,
#  '龚正': 1,
#  '魏礼群': 1,
#  '本刊文化编辑部、大庆油田党委联合调研组': 1,
#  '李荣灿': 1,
#  '佟明增': 1,
#  '钟轩理': 1,
#  '刘奇': 1,
#  '李军': 1,
#  '孙继炼': 1,
#  '曲建武': 1,
#  '杨治钊': 1,
#  '王国生': 1,
#  '胡和平': 1,
#  '骆惠宁': 2,
#  '周树春': 1,
#  '李掖平': 1,
#  '潘文革': 1,
#  '《前线》特约评论员': 1,
#  '陈希': 1,
#  '肖捷': 1,
#  '王建军': 2,
#  '荆博': 1,
#  '庞高杰': 1,
#  '高尚': 1,
#  '巴特尔': 1,
#  '傅自应': 1,
#  '李玉赋': 1,
#  '张季': 1,
#  '李炳军': 1,
#  '吴强': 1,
#  '晏然': 1,
#  '阳明': 1,
#  '舒启明': 1,
#  '苗庆旺': 1,
#  '袁誉柏': 1,
#  '王建武': 1,
#  '仲组轩': 1,
#  '中央纪委国家监委法规室': 1,
#  '中国石油化工集团有限公司党组': 1,
#  '唐顺利': 1}

# %%
len(author_article_count)
# Out:
# 955

# %%
author_article_count["张芯蕊"]
# Out:
# 1

# %%
sorted_author_article_count = {k: v for k, v in sorted(author_article_count.items(), key=lambda item: item[1], 
                                                       reverse=True) if v >= 10}
sorted_author_article_count
# Out:
# {'习近平': 123,
#  '《求是》杂志评论员': 76,
#  '《求是》杂志编辑部': 72,
#  '本刊编辑部': 47,
#  '新华社记者': 38,
#  '本刊评论员': 19,
#  '同心': 14,
#  '宁吉喆': 13,
#  '梁佩韵': 12,
#  '侯亚景': 12,
#  '巨力': 12,
#  '王毅': 11,
#  '黎海华': 10,
#  '狄英娜': 10,
#  '慎海雄': 10,
#  '曲青山': 10,
#  '中共中央党史和文献研究院': 10}

# %%
df = pd.DataFrame.from_dict(sorted_author_article_count, 'index', columns=['article_count'])
df.to_excel('./author_info/all_authors.xlsx')
df
# Out:
#               article_count
# 习近平                     123
# 《求是》杂志评论员                76
# 《求是》杂志编辑部                72
# 本刊编辑部                    47
# 新华社记者                    38
# 本刊评论员                    19
# 同心                       14
# 宁吉喆                      13
# 梁佩韵                      12
# 侯亚景                      12
# 巨力                       12
# 王毅                       11
# 黎海华                      10
# 狄英娜                      10
# 慎海雄                      10
# 曲青山                      10
# 中共中央党史和文献研究院             10

# %%
len(sorted_author_article_count)
# Out:
# 17

# %%
print('Proportion of articles with author identified authored by 10+ article authors: {:.3f}'.format(sum(sorted_author_article_count.values()) / articles_w_author))
print('Proportion of all articles authored by 10+ article authors: {:.3f}'.format(sum(sorted_author_article_count.values()) / total_articles))
# Out:
# Proportion of articles with author identified authored by 10+ article authors: 0.291
# Proportion of all articles authored by 10+ article authors: 0.248

# %%
# remove the organizations, preserving just individuals - anything with more than 4 characters get axed
for key in list(sorted_author_article_count.keys()):
    if len(key) > 4:
        sorted_author_article_count.pop(key)

sorted_author_article_count
# Out:
# {'习近平': 123,
#  '同心': 14,
#  '宁吉喆': 13,
#  '梁佩韵': 12,
#  '侯亚景': 12,
#  '巨力': 12,
#  '王毅': 11,
#  '黎海华': 10,
#  '狄英娜': 10,
#  '慎海雄': 10,
#  '曲青山': 10}

# %%
df = pd.DataFrame.from_dict(sorted_author_article_count, 'index', columns=['article_count'])
df.to_excel('./author_info/individual_authors.xlsx')

# %%
print('Proportion of articles with author identified authored by individuals with 10+ articles: {:.3f}'.format(sum(sorted_author_article_count.values()) / articles_w_author))
print('Proportion of all articles authored by individuals with 10+ articles: {:.3f}'.format(sum(sorted_author_article_count.values()) / total_articles))
# Out:
# Proportion of articles with author identified authored by individuals with 10+ articles: 0.138
# Proportion of all articles authored by individuals with 10+ articles: 0.118
